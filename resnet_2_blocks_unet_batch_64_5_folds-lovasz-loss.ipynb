# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time


import tqdm
from skimage.transform import resize,rotate
from skimage.color import rgb2gray

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import *
from keras import backend as K
from keras.losses import *

from sklearn.model_selection import train_test_split,StratifiedKFold
import tensorflow as tf

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
# Set some parameters
n_pixels = 128
channels = 1
path_train = 'train/'
path_test = 'test/'

# %%
train=pd.read_csv("train/train.csv")
print(train.shape)
train.head()
# Out:
# (4000, 2)
#            id                                           rle_mask
# 0  575d24d81d                                                NaN
# 1  a266a2a9df                                          5051 5151
# 2  75efad62c1  9 93 109 94 210 94 310 95 411 95 511 96 612 96...
# 3  34e51dba6a  48 54 149 54 251 53 353 52 455 51 557 50 659 4...
# 4  4875705fb0  1111 1 1212 1 1313 1 1414 1 1514 2 1615 2 1716...

# %%
sample=pd.read_csv("sample_submission.csv")
print(sample.shape)
sample.head()
# Out:
# (18000, 2)
#            id rle_mask
# 0  155410d6fa      1 1
# 1  78b32781d1      1 1
# 2  63db2a476a      1 1
# 3  17bfcdb967      1 1
# 4  7ea0fd3c88      1 1

# %%
depth=pd.read_csv("depths.csv")
print(depth.shape)
depth.head()
# Out:
# (22000, 2)
#            id    z
# 0  4ac19fb269  306
# 1  1825fadf99  157
# 2  f59821d067  305
# 3  5b435fad9d  503
# 4  e340e7bfca  783

# %%
train_ids = train.id.values
test_ids = sample.id.values

# %%
resize_mode='constant'

# Get and resize train images and masks
X = np.zeros((len(train_ids), n_pixels, n_pixels, channels), dtype=np.uint8)
y = np.zeros((len(train_ids), n_pixels, n_pixels, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
for n, id_ in tqdm.tqdm_notebook(enumerate(train_ids),total=len(train_ids)):
    path = path_train
    x = np.array(load_img(path + '/images/' + id_+".png",color_mode='grayscale'))
    x = resize(x, (n_pixels,n_pixels, channels), mode=resize_mode, 
               preserve_range=True,clip=True,anti_aliasing=False)
    X[n] = x
    mask = np.array(load_img(path + '/masks/' + id_+".png",color_mode='grayscale'))
    y[n] = resize(mask, (n_pixels,n_pixels,1), mode=resize_mode, 
                  preserve_range=True,clip=True,anti_aliasing=False)

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# Done!

# %% [markdown]
# ## TEST DATA

# %%
# Get and resize test images
X_test = np.zeros((len(test_ids),n_pixels,n_pixels,channels), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm.tqdm_notebook(enumerate(test_ids), total=len(test_ids)):
    path = path_test
    x= np.array(load_img(path + '/images/' + id_+".png",color_mode='grayscale'))
    x = resize(x, (n_pixels,n_pixels, 1), mode=resize_mode, 
               preserve_range=True,clip=True,anti_aliasing=False)
    X_test[n] = x

print('Done!')
# Out:
# Getting and resizing test images ...
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Done!

# %%
# storing empty images 


p=np.ones((4000,))
for i in range(4000):
    p[i]=np.sum(X[i,:,:,:])/(128*128)

trainindex=[]
for j,i in enumerate(p):
    if i==0:
        trainindex.append(j)
        
        
print(len(trainindex))
print(trainindex)
# Out:
# 80
# [37, 57, 90, 121, 136, 143, 211, 218, 262, 270, 314, 506, 550, 638, 738, 995, 1084, 1394, 1436, 1478, 1567, 1609, 1614, 1623, 1629, 1646, 1695, 1698, 1743, 1773, 1834, 1839, 1842, 1894, 1923, 1928, 1938, 1957, 1986, 2008, 2057, 2192, 2293, 2391, 2393, 2454, 2477, 2521, 2677, 2713, 2725, 2771, 2785, 2799, 2838, 2852, 2882, 2939, 2953, 3015, 3036, 3107, 3206, 3233, 3281, 3362, 3426, 3432, 3502, 3533, 3536, 3640, 3647, 3673, 3684, 3736, 3746, 3779, 3966, 3986]

# %%
# storing empty images

q=np.ones((18000,))
for i in range(18000):
    q[i]=np.sum(X_test[i,:,:,:])/(128*128)
    
indextest=[]
for j,i in enumerate(q):
    if i==0:
        indextest.append(j)
        
print(len(indextest))
print(indextest)
# Out:
# 430
# [67, 128, 137, 138, 172, 183, 220, 251, 273, 373, 377, 385, 404, 496, 513, 551, 638, 656, 665, 704, 837, 844, 854, 905, 915, 919, 954, 995, 1119, 1166, 1175, 1217, 1270, 1291, 1309, 1337, 1348, 1470, 1492, 1499, 1537, 1586, 1588, 1596, 1609, 1627, 1648, 1650, 1656, 1771, 1842, 1845, 1855, 1872, 1924, 1925, 2021, 2033, 2139, 2184, 2220, 2265, 2323, 2341, 2432, 2502, 2603, 2727, 2767, 2780, 2854, 2996, 3043, 3079, 3211, 3286, 3384, 3503, 3514, 3552, 3654, 3666, 3668, 3721, 3724, 3761, 3804, 3810, 3906, 3928, 3963, 4008, 4031, 4044, 4055, 4098, 4109, 4121, 4202, 4218, 4271, 4290, 4295, 4297, 4363, 4424, 4526, 4561, 4569, 4599, 4634, 4723, 4725, 4727, 4741, 4755, 4863, 4883, 4889, 4900, 4904, 4990, 5125, 5132, 5189, 5215, 5224, 5291, 5327, 5341, 5385, 5409, 5430, 5512, 5524, 5576, 5702, 5760, 5777, 5920, 6008, 6039, 6098, 6104, 6140, 6155, 6162, 6211, 6238, 6244, 6335, 6367, 6448, 6454, 6479, 6481, 6488, 6534, 6540, 6556, 6663, 6697, 6766, 6805, 6843, 6879, 6893, 6929, 6942, 6973, 7044, 7154, 7224, 7229, 7249, 7267, 7388, 7390, 7421, 7429, 7440, 7452, 7473, 7515, 7524, 7598, 7662, 7705, 7776, 7863, 7921, 7928, 8003, 8105, 8134, 8158, 8215, 8217, 8242, 8277, 8304, 8332, 8351, 8383, 8399, 8443, 8450, 8505, 8515, 8521, 8635, 8719, 8730, 8772, 8794, 8795, 8826, 8856, 8887, 8957, 8991, 8995, 9141, 9169, 9173, 9204, 9284, 9304, 9314, 9358, 9410, 9416, 9426, 9476, 9482, 9515, 9616, 9625, 9683, 9702, 9803, 9835, 9836, 9880, 9964, 10005, 10031, 10035, 10051, 10106, 10131, 10155, 10164, 10226, 10240, 10344, 10432, 10531, 10548, 10553, 10577, 10607, 10625, 10638, 10716, 10723, 10724, 10754, 10851, 10886, 10889, 10944, 10956, 10962, 11068, 11091, 11097, 11102, 11148, 11226, 11252, 11267, 11316, 11397, 11449, 11474, 11529, 11561, 11588, 11595, 11678, 11746, 11802, 11844, 11870, 11990, 12031, 12047, 12166, 12207, 12224, 12260, 12361, 12401, 12411, 12485, 12536, 12570, 12655, 12663, 12666, 12787, 12818, 13034, 13245, 13248, 13257, 13275, 13310, 13356, 13381, 13440, 13504, 13525, 13573, 13610, 13711, 13769, 13778, 13794, 13821, 13927, 13934, 13936, 14108, 14170, 14185, 14218, 14231, 14264, 14290, 14291, 14376, 14427, 14470, 14477, 14577, 14578, 14594, 14669, 14684, 14734, 14792, 14866, 14876, 14894, 14899, 15015, 15018, 15133, 15151, 15163, 15184, 15296, 15331, 15389, 15405, 15446, 15466, 15602, 15636, 15675, 15823, 15868, 15979, 15988, 16018, 16067, 16129, 16163, 16186, 16209, 16223, 16275, 16292, 16300, 16343, 16344, 16365, 16387, 16408, 16433, 16442, 16452, 16455, 16489, 16498, 16521, 16605, 16701, 16732, 16748, 16792, 16794, 16897, 16906, 16982, 16993, 16995, 17040, 17050, 17152, 17221, 17225, 17260, 17272, 17293, 17303, 17325, 17330, 17497, 17502, 17507, 17550, 17761, 17824, 17868, 17927, 17939, 17993]

# %% [markdown]
# ## STRATIFICATION
#
# Calculating the salt coverage class

# %%
coverage=np.zeros((train_ids.shape[0],))
for i,name in tqdm.tqdm_notebook(enumerate(train_ids),total=train_ids.shape[0]):
    coverage[i]=np.sum(y[i,:,:,0])

train['coverage']=pd.Series(coverage)/y.shape[1]**2

print(train.shape)
train.head()
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# (4000, 3)
#            id                                           rle_mask  coverage
# 0  575d24d81d                                                NaN  0.000000
# 1  a266a2a9df                                          5051 5151  0.507812
# 2  75efad62c1  9 93 109 94 210 94 310 95 411 95 511 96 612 96...  0.994507
# 3  34e51dba6a  48 54 149 54 251 53 353 52 455 51 557 50 659 4...  0.155029
# 4  4875705fb0  1111 1 1212 1 1313 1 1414 1 1514 2 1615 2 1716...  0.048401

# %%
def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train["coverage_class"] = train.coverage.apply(cov_to_class)

print(train.shape)
train.head()
# Out:
# (4000, 4)
#            id                                           rle_mask  coverage  \
# 0  575d24d81d                                                NaN  0.000000
# 1  a266a2a9df                                          5051 5151  0.507812
# 2  75efad62c1  9 93 109 94 210 94 310 95 411 95 511 96 612 96...  0.994507
# 3  34e51dba6a  48 54 149 54 251 53 353 52 455 51 557 50 659 4...  0.155029
# 4  4875705fb0  1111 1 1212 1 1313 1 1414 1 1514 2 1615 2 1716...  0.048401
#
#    coverage_class
# 0               0
# 1               6
# 2              10
# 3               2
# 4               1

# %%
## coverage class numpy array
coverage=train.coverage_class.values
print(coverage.shape)
# Out:
# (4000,)

# %%
train.loc[train['coverage']==0].shape
# Out:
# (1562, 4)

# %% [markdown]
# ## AUGMENTATION

# %%
ind=3

p=rotate(X[ind,:,:,0].astype(np.uint8),angle=10,order=1,mode='reflect',
                clip=True,preserve_range=True)
q=rotate(y[ind,:,:,0].astype(np.uint8),angle=10,order=1,mode='reflect',
         clip=True,preserve_range=True)

plt.figure(figsize=(12,7))

plt.subplot(221)
plt.imshow(X[ind].reshape(128,128),cmap='gist_gray')
plt.subplot(222)
plt.imshow(y[ind].reshape(128,128),cmap='gist_gray')
plt.subplot(223)
plt.imshow(p.astype(np.uint8).reshape(128,128),cmap='gist_gray')
plt.subplot(224)
plt.imshow(q.astype(np.uint8).reshape(128,128),cmap='gist_gray')

plt.tight_layout()
plt.show()

# %%
def crop_rescale_image(image,mask,state,limit):
    np.random.seed(state)
    h,w=image.shape[0],image.shape[1]
    dy=int(h*limit)
    y0=np.random.randint(int(0.1*h),dy)
    y1=h-y0
    
    
    np.random.seed(state+5000)
    dx=int(w*limit)
    x0=np.random.randint(int(0.1*w),dx)
    x1=w-x0
    
    m='reflect'
#     print(y0,x0)
    cropped_image=resize(image[y0:y1,x0:x1,:],(h,w),mode=m,
                         preserve_range=True,anti_aliasing=False)
    cropped_mask=resize(mask[y0:y1,x0:x1,:],(h,w),mode=m,
                        preserve_range=True,anti_aliasing=False)

    
    return cropped_image,cropped_mask
    
def random_crop_rescale(X,y,limit):
    m=X.shape[0]
    processed_image=np.zeros(X.shape)
    processed_mask=np.zeros(y.shape)
    for i in range(m):
        processed_image[i,:,:,:],processed_mask[i,:,:,:]=crop_rescale_image(X[i,:,:,:],y[i,:,:,:],i,limit)
    
    return processed_image.astype(np.uint8),processed_mask.astype(np.uint8)


def rotate_grp(images,masks,ang):
    rotated_images=np.zeros((images.shape))
    rotated_masks=np.zeros((masks.shape))
    for i in range(images.shape[0]):
        rotated_images[i,:,:,0]=rotate(X[i,:,:,0].astype(np.uint8),angle=ang,order=1,mode='reflect',
                clip=True,preserve_range=True)
        rotated_masks[i,:,:,0]=q=rotate(y[ind,:,:,0].astype(np.uint8),angle=ang,order=1,mode='reflect',
         clip=True,preserve_range=True)
        
        
    return rotated_images.astype(np.uint8),rotated_masks.astype(np.uint8)

# %%
def augment(X,y,l,start_crop,end_crop,start_rot,end_rot,start_roll=-1,end_roll=-1,rolling=False):
    m=X.shape[0]
    print("Flipping")
    X=np.append(X,[np.fliplr(x) for x in X],axis=0)
    y=np.append(y,[np.fliplr(i) for i in y],axis=0)

    # trying random crop and rescale
    np.random.seed(42)
    index=np.arange(0,m)
    # shuffling the array
    np.random.shuffle(index)

    print("Random crop and resize")
    # random crop and resize
    processed_X,processed_y=random_crop_rescale(X[index[start_crop:end_crop]],
                                                y[index[start_crop:end_crop]],limit=l)
    X=np.append(X,processed_X,axis=0)
    y=np.append(y,processed_y,axis=0)

    print("Rotations")
    # 10 degree rotation
    rotated_X,rotated_y=rotate_grp(X[index[start_rot:end_rot]],
                                   y[index[start_rot:end_rot]],ang=10)

    X=np.append(X,rotated_X,axis=0)
    y=np.append(y,rotated_y,axis=0)
    
    if rolling:
        print("Rolling")
        
        roll_index=np.arange(0,X.shape[0])
        
        # shuffling
        np.random.shuffle(roll_index)
        
        # rolling train and mask
        to_roll_X=X[roll_index[start_roll:end_roll]]
        to_roll_y=y[roll_index[start_roll:end_roll]]
            
        # 40 steps rolling
        X=np.append(X,[np.roll(x, 40, axis = 1) for x in to_roll_X], axis = 0)
        y=np.append(y,[np.roll(t,40,axis=1) for t in to_roll_y],axis=0)
        
    return X,y

# %%
# # split

# X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.1,stratify=coverage,random_state=42)

# print(X_train.shape,X_val.shape)
# print(y_train.shape,y_val.shape)

# %%
# print("Training Data Augmentation:")
# print("Before Augmentation:",X_train.shape,y_train.shape)

# X_train,y_train=augment(X_train,y_train,l=0.3,start_crop=0,end_crop=1000,start_rot=1000,
#                         end_rot=2000,start_roll=0,end_roll=2000,rolling=True)

# print("After Augmentation ",X_train.shape,y_train.shape)

# print("Validation Augmentation:")
# print("Before Augmentation:",X_val.shape,y_val.shape)

# X_val,y_val=augment(X_val,y_val,l=0.3,start_crop=0,end_crop=150,start_rot=150,
#                     end_rot=300,start_roll=0,end_roll=200,rolling=True)

# print("After Augmentation:",X_val.shape,y_val.shape)

# %%
# metric

def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))
        
    return np.mean(metric)

def competition_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)
        
# for lovasz the threshold is zero
def metric_for_lovasz(label,pred):
    return tf.py_func(get_iou_vector,[label,pred>0],tf.float64)


def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# loss
# here i will add dice and bce loss
# taken from https://www.kaggle.com/kmader/u-net-with-dice-and-augmentation

def dice_loss(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    score=K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)
    return 1.0-score

def dice_and_bce(in_gt, in_pred):
    """combine DICE and BCE"""
    return binary_crossentropy(in_gt, in_pred) + dice_loss(in_gt, in_pred)

# %% [markdown]
# ### LOVASZ LOSS

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %% [markdown]
# ## ARCHITECUTE

# %%
def batch_activate(x,normalize=True,do_activation=True):
    output=x
    if normalize:
        output=BatchNormalization()(output)
    if do_activation:
        output=Activation(activation='relu')(output)
        
    return output

def residual_block(inputs,fil,match_channel=False):
    x=batch_activate(inputs,normalize=True,do_activation=True)
    
    # 3x3 convolutions
    x=Conv2D(fil,(3,3),padding='same',activation=None,use_bias=False)(x)
    
    # batch norm and relu
    x=batch_activate(x,normalize=True,do_activation=True)
    
    # 3x3 convolutions
    x=Conv2D(fil,(3,3),padding='same',activation=None,use_bias=False)(x)
    
    if match_channel:
        inputs=Conv2D(fil,(1,1),padding='same',activation=None,use_bias=False)(inputs)
    
    if x.shape[3]==inputs.shape[3]:
        p=Add()([x,inputs])
        return p
    else:
        print("The number of channels are not same")
        return -1


def model_call():
    inputs = Input(shape = (n_pixels,n_pixels, channels))

    normalize=True
    batch_normalize=True

    if normalize:
        s=Lambda(lambda x: x / 255) (inputs)
    else:
        s=inputs
    
    ch=16
    # c1=Conv2D(ch,(3,3),activation=None,use_bias=False,padding='same')(s)

    # 128 to 64
    c1 = residual_block(s,ch,match_channel=True)
    c1 = residual_block(c1,ch,match_channel=False)
    c1 =  BatchNormalization()(c1) if batch_normalize else c1
    p1 = MaxPooling2D(pool_size=(2, 2))(c1)

    # 64 to 32
    c2 = residual_block(p1,2*ch,match_channel=True)
    c2 = residual_block(c2,2*ch,match_channel=False)
    c2 = BatchNormalization()(c2) if batch_normalize else c2
    p2 = MaxPooling2D(pool_size = (2, 2))(c2)

    # 32 to 16
    c3 = residual_block(p2,4*ch,match_channel=True)
    c3 = residual_block(c3,4*ch,match_channel=False)
    c3 = BatchNormalization()(c3) if batch_normalize else c3
    p3 = MaxPooling2D(pool_size = (2, 2))(c3)


    # 16 to 8
    c4 = residual_block(p3,8*ch,match_channel=True)
    c4 = residual_block(c4,8*ch,match_channel=False)
    c4 = BatchNormalization()(c4) if batch_normalize else c4
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)


    # 16 to 8
    c5 = residual_block(p4, 16*ch, match_channel=True)
    c5 = residual_block(c5, 16*ch, match_channel=False)
    c5 = BatchNormalization()(c5) if batch_normalize else c5

    # 8 to 16
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), activation = "relu",padding = "same")(c5)
    u6 = concatenate([u6, c4]) # 256 shape
    c6 = residual_block(u6,8*ch,match_channel=True)
    c6 = residual_block(c6,8*ch,match_channel=False)
    c6 = BatchNormalization()(c6) if batch_normalize else c6

    # 16 to 32
    u7 = Conv2DTranspose(64, (2, 2), strides = (2, 2,), activation = "relu",padding = "same")(c6)
    u7 = concatenate([u7, c3]) # 128  shape
    c7 = residual_block(u7,4*ch,match_channel=True)
    c7 = residual_block(c7,4*ch,match_channel=False)
    c7 = BatchNormalization()(c7) if batch_normalize else c7

    # 32 to 64
    u8 = Conv2DTranspose(32, (2, 2), strides = (2, 2), activation = "relu",padding = "same")(c7)
    u8 = concatenate([u8, c2]) # 64 shape
    c8 = residual_block(u8,2*ch,match_channel=True)
    c8 = residual_block(c8,2*ch,match_channel=False)
    c8 = BatchNormalization()(c8) if batch_normalize else c8

    # 64 to 128
    u9 = Conv2DTranspose(16, (2, 2), strides = (2, 2), activation = "relu",padding = "same")(c8)
    u9 = concatenate([u9, c1])   # 32 shape
    c9 = residual_block(u9,ch,match_channel=True)
    c9 = residual_block(c9,ch,match_channel=False)
    c9 = BatchNormalization()(c9) if batch_normalize else c9

    output_without_activation = Conv2D(1, (1, 1), activation = None,use_bias=False)(c9)

    outputs=Activation(activation='sigmoid')(output_without_activation)

    model = Model(inputs = [inputs], outputs = [outputs])
    optimizer = Adam()

    model.compile(optimizer = optimizer, loss = "binary_crossentropy", metrics = [competition_metric])
#     model.summary()

    
    return model

# %% [markdown]
# ## INITIALIZATIONS AND FIT DATA FUNCTION

# %%
def create_callbacks(name_model,montior_quan,inc_earlystopper=True,inc_checkpointer=True,inc_lr=True,init_lr=True,init_early_stopper=True,
                 init_checkpointer=True,early_stopper=None,check_pointer=None,reduce_lr=None):
    
    callback=[]
    
    if inc_earlystopper:
        earlystopper=None
        # if early stopper is included then 
        if init_early_stopper:
            # to initialize the early stopper
            earlystopper = EarlyStopping(monitor=montior_quan,patience=15,
                             mode='max',verbose=1)
        else:
            # make the early stopper given by user
            if early_stopper!=None:
                earlystopper=early_stopper
            else:
                print("Error Not given early stopper")
    
        callback.append(earlystopper)
        
    if inc_lr:
        reduce_lr=None
        if init_lr:
            reducelr=ReduceLROnPlateau(monitor=montior_quan,patience=5, 
                            min_lr=0.00001,mode='max',verbose=1,factor=0.5)
        else:
            if reduce_lr!=None:
                reducelr=reduce_lr
            else:
                print("Error Not given reduce lr on plateau")
        
        callback.append(reducelr)
        
    if inc_checkpointer:
        checkpointer=None
        if init_checkpointer:
            checkpointer = ModelCheckpoint(name_model, monitor=montior_quan,mode='max',
                               verbose=1, save_best_only=True)
        else:
            if check_pointer!=None:
                checkpointer=check_pointer
            else:
                print("Error not given model checkpointer")
    
        callback.append(checkpointer)
        
    return callback

def fit_data(model,X_train,y_train,X_val,y_val,batches,ep,name_model,verb,monitor_quan,
                inc_earlystopper=True,inc_checkpointer=True,inc_lr=True,init_lr=True,init_early_stopper=True,
                 init_checkpointer=True,early_stopper=None,check_pointer=None,reduce_lr=None):
    
    # callbacks initialization
    callback=create_callbacks(name_model,monitor_quan,inc_earlystopper,inc_checkpointer,inc_lr,init_lr,
                              init_early_stopper,init_checkpointer,early_stopper,check_pointer,reduce_lr)
    
    
    results = model.fit(X_train, y_train, validation_data=[X_val,y_val], 
                        batch_size=batches, epochs=ep, callbacks=callback,verbose=verb)
    
    return results
    
    
def create_model_for_loavsz(model1):
    # remove layter activation layer and use losvasz loss
    input_x = model1.layers[0].input

    output_layer = model1.layers[-1].input
    model = Model(input_x, output_layer)
    c = adam()

    # lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
    # Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
    model.compile(loss=lovasz_loss, optimizer=c, metrics=[metric_for_lovasz])

#     model.summary()

    return model

# %%
# training
n_folds=5
kfold=StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=42)
preds_test=np.zeros((18000,128,128,1))
preds_test_flip=np.zeros((18000,128,128,1))

for fold,(train_index,val_index) in enumerate(kfold.split(X,coverage)):
    X_train,X_val=X[train_index],X[val_index]
    y_train,y_val=y[train_index],y[val_index]
    
    print("================================= FOLD",fold+1,"=============================================")
    
     
    print(X_train.shape,X_val.shape)
    
    # augmentation
    print("Training Augmentation")
    X_train,y_train=augment(X_train,y_train,l=0.3,start_crop=0,end_crop=1600,
                            start_rot=1600,end_rot=3200,start_roll=0,end_roll=4000,rolling=True)

    print("Validation Augmentation")
    X_val,y_val=augment(X_val,y_val,l=0.3,start_crop=0,end_crop=800,
                        start_rot=0,end_rot=800,start_roll=0,end_roll=3000,rolling=True)
    
    
    print("Data shape")
    print(X_train.shape,X_val.shape)
    
    
    model=model_call()
    
    save_name='models/resnet_unet_kfold_lovasz_'+str(fold+1)+'.h5'
    
    
    # first it is binary cross entropy.
    
    batch_size=64
    epochs=80
    verbose=0
    
    monitor_quantity = 'val_competition_metric'
    
    result=fit_data(model,X_train,y_train,X_val,y_val,batch_size,
                    epochs,name_model=save_name,verb=verbose,monitor_quan=monitor_quantity)
    
    print("Done with binary cross entropy")
    
    # fit done and now we have to use lovasz loss
    
    # loading the best model
    model1=load_model(save_name,custom_objects={'competition_metric': competition_metric})
    
    # creating the model for loavsz 
    model=create_model_for_loavsz(model1)
    
    print("Model ready for lovasz training")
    
    batch_size=64
    epochs=80
    verbose=0
    
    monitor_quantity = 'val_metric_for_lovasz'    
    
    result=fit_data(model,X_train,y_train,X_val,y_val,batch_size,
                    epochs,name_model=save_name,verb=verbose,monitor_quan=monitor_quantity)

    
    print("Done with training in this fold")

    # loading the final model
    model = load_model(save_name, custom_objects={'metric_for_lovasz': metric_for_lovasz,
                                                   'lovasz_loss': lovasz_loss})
    

    print(model.metrics_names)
    print(model.evaluate(X_val,y_val))
    
    # making test predictions
    preds_test=preds_test+(model.predict(X_test,verbose=1))/n_folds
    
    # tta
    X_test_flip=np.array([np.fliplr(x) for x in X_test])
    flipping_predictions=model.predict(X_test_flip,verbose=1)
    
    # now i have to flip these predictions
    flipping_predictions=np.array([np.fliplr(x) for x in flipping_predictions])
    
    # saving the predictions 
    preds_test_flip=preds_test_flip+flipping_predictions/n_folds
# Out:
# ================================= FOLD 1 =============================================
# (3196, 128, 128, 1) (804, 128, 128, 1)
# Training Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Validation Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Data shape
# (13588, 128, 128, 1) (6208, 128, 128, 1)
#
# Epoch 00001: val_competition_metric improved from -inf to 0.13476, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00002: val_competition_metric improved from 0.13476 to 0.24169, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00003: val_competition_metric did not improve from 0.24169
#
# Epoch 00004: val_competition_metric improved from 0.24169 to 0.58357, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00005: val_competition_metric improved from 0.58357 to 0.59019, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00006: val_competition_metric improved from 0.59019 to 0.67740, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00007: val_competition_metric improved from 0.67740 to 0.72052, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00008: val_competition_metric improved from 0.72052 to 0.72460, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00009: val_competition_metric did not improve from 0.72460
#
# Epoch 00010: val_competition_metric improved from 0.72460 to 0.75672, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00011: val_competition_metric did not improve from 0.75672
#
# Epoch 00012: val_competition_metric did not improve from 0.75672
#
# Epoch 00013: val_competition_metric did not improve from 0.75672
#
# Epoch 00014: val_competition_metric did not improve from 0.75672
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_competition_metric did not improve from 0.75672
#
# Epoch 00016: val_competition_metric improved from 0.75672 to 0.79024, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00017: val_competition_metric improved from 0.79024 to 0.79296, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00018: val_competition_metric did not improve from 0.79296
#
# Epoch 00019: val_competition_metric did not improve from 0.79296
#
# Epoch 00020: val_competition_metric improved from 0.79296 to 0.79467, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00021: val_competition_metric did not improve from 0.79467
#
# Epoch 00022: val_competition_metric did not improve from 0.79467
#
# Epoch 00023: val_competition_metric did not improve from 0.79467
#
# Epoch 00024: val_competition_metric did not improve from 0.79467
#
# Epoch 00025: val_competition_metric improved from 0.79467 to 0.79686, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00026: val_competition_metric did not improve from 0.79686
#
# Epoch 00027: val_competition_metric did not improve from 0.79686
#
# Epoch 00028: val_competition_metric did not improve from 0.79686
#
# Epoch 00029: val_competition_metric did not improve from 0.79686
#
# Epoch 00030: val_competition_metric improved from 0.79686 to 0.79771, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00031: val_competition_metric did not improve from 0.79771
#
# Epoch 00032: val_competition_metric did not improve from 0.79771
#
# Epoch 00033: val_competition_metric did not improve from 0.79771
#
# Epoch 00034: val_competition_metric did not improve from 0.79771
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00035: val_competition_metric did not improve from 0.79771
#
# Epoch 00036: val_competition_metric improved from 0.79771 to 0.79892, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00037: val_competition_metric did not improve from 0.79892
#
# Epoch 00038: val_competition_metric improved from 0.79892 to 0.79998, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00039: val_competition_metric did not improve from 0.79998
#
# Epoch 00040: val_competition_metric improved from 0.79998 to 0.80047, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00041: val_competition_metric did not improve from 0.80047
#
# Epoch 00042: val_competition_metric did not improve from 0.80047
#
# Epoch 00043: val_competition_metric did not improve from 0.80047
#
# Epoch 00044: val_competition_metric did not improve from 0.80047
#
# Epoch 00045: val_competition_metric improved from 0.80047 to 0.80496, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00046: val_competition_metric did not improve from 0.80496
#
# Epoch 00047: val_competition_metric did not improve from 0.80496
#
# Epoch 00048: val_competition_metric did not improve from 0.80496
#
# Epoch 00049: val_competition_metric did not improve from 0.80496
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00050: val_competition_metric did not improve from 0.80496
#
# Epoch 00051: val_competition_metric did not improve from 0.80496
#
# Epoch 00052: val_competition_metric did not improve from 0.80496
#
# Epoch 00053: val_competition_metric did not improve from 0.80496
#
# Epoch 00054: val_competition_metric did not improve from 0.80496
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00055: val_competition_metric did not improve from 0.80496
#
# Epoch 00056: val_competition_metric did not improve from 0.80496
#
# Epoch 00057: val_competition_metric did not improve from 0.80496
#
# Epoch 00058: val_competition_metric did not improve from 0.80496
#
# Epoch 00059: val_competition_metric did not improve from 0.80496
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00060: val_competition_metric did not improve from 0.80496
# Epoch 00060: early stopping
# Done with binary cross entropy
# Model ready for lovasz training
#
# Epoch 00001: val_metric_for_lovasz improved from -inf to 0.78872, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00002: val_metric_for_lovasz improved from 0.78872 to 0.80501, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00003: val_metric_for_lovasz did not improve from 0.80501
#
# Epoch 00004: val_metric_for_lovasz did not improve from 0.80501
#
# Epoch 00005: val_metric_for_lovasz did not improve from 0.80501
#
# Epoch 00006: val_metric_for_lovasz improved from 0.80501 to 0.80598, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00007: val_metric_for_lovasz did not improve from 0.80598
#
# Epoch 00008: val_metric_for_lovasz did not improve from 0.80598
#
# Epoch 00009: val_metric_for_lovasz did not improve from 0.80598
#
# Epoch 00010: val_metric_for_lovasz did not improve from 0.80598
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_metric_for_lovasz did not improve from 0.80598
#
# Epoch 00012: val_metric_for_lovasz improved from 0.80598 to 0.81513, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00013: val_metric_for_lovasz improved from 0.81513 to 0.81983, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00014: val_metric_for_lovasz did not improve from 0.81983
#
# Epoch 00015: val_metric_for_lovasz improved from 0.81983 to 0.82118, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00016: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00017: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00018: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00019: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00021: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00022: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00023: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00024: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_metric_for_lovasz did not improve from 0.82118
#
# Epoch 00026: val_metric_for_lovasz improved from 0.82118 to 0.82179, saving model to models/resnet_unet_kfold_lovasz_1.h5
#
# Epoch 00027: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00028: val_metric_for_lovasz did not improve from 0.82179
# Epoch 00029: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00030: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00031: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00032: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00033: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00034: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00035: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00036: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00037: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00038: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00039: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00040: val_metric_for_lovasz did not improve from 0.82179
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00041: val_metric_for_lovasz did not improve from 0.82179
# Epoch 00041: early stopping
# Done with training in this fold
# ['loss', 'metric_for_lovasz']
# 6208/6208 [==============================] - 95s 15ms/step
# [0.3290795250852039, 0.8217944587628868]
# 18000/18000 [==============================] - 24s 1ms/step
# 18000/18000 [==============================] - 23s 1ms/step
# ================================= FOLD 2 =============================================
# (3197, 128, 128, 1) (803, 128, 128, 1)
# Training Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Validation Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Data shape
# (13591, 128, 128, 1) (6206, 128, 128, 1)
#
# Epoch 00001: val_competition_metric improved from -inf to 0.13116, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00002: val_competition_metric improved from 0.13116 to 0.31097, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00003: val_competition_metric did not improve from 0.31097
#
# Epoch 00004: val_competition_metric improved from 0.31097 to 0.48730, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00005: val_competition_metric improved from 0.48730 to 0.50073, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00006: val_competition_metric improved from 0.50073 to 0.52025, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00007: val_competition_metric improved from 0.52025 to 0.65661, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00008: val_competition_metric improved from 0.65661 to 0.73331, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00009: val_competition_metric did not improve from 0.73331
#
# Epoch 00010: val_competition_metric improved from 0.73331 to 0.73580, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00011: val_competition_metric improved from 0.73580 to 0.74170, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00012: val_competition_metric improved from 0.74170 to 0.75367, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00013: val_competition_metric improved from 0.75367 to 0.76236, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00014: val_competition_metric improved from 0.76236 to 0.76855, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00015: val_competition_metric improved from 0.76855 to 0.77005, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00016: val_competition_metric improved from 0.77005 to 0.78033, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00017: val_competition_metric did not improve from 0.78033
#
# Epoch 00018: val_competition_metric did not improve from 0.78033
#
# Epoch 00019: val_competition_metric did not improve from 0.78033
#
# Epoch 00020: val_competition_metric did not improve from 0.78033
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00021: val_competition_metric did not improve from 0.78033
#
# Epoch 00022: val_competition_metric improved from 0.78033 to 0.78716, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00023: val_competition_metric improved from 0.78716 to 0.80994, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00024: val_competition_metric did not improve from 0.80994
#
# Epoch 00025: val_competition_metric did not improve from 0.80994
#
# Epoch 00026: val_competition_metric did not improve from 0.80994
#
# Epoch 00027: val_competition_metric did not improve from 0.80994
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_competition_metric did not improve from 0.80994
#
# Epoch 00029: val_competition_metric improved from 0.80994 to 0.81091, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00030: val_competition_metric did not improve from 0.81091
#
# Epoch 00031: val_competition_metric did not improve from 0.81091
#
# Epoch 00032: val_competition_metric did not improve from 0.81091
#
# Epoch 00033: val_competition_metric did not improve from 0.81091
#
# Epoch 00034: val_competition_metric improved from 0.81091 to 0.81416, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00035: val_competition_metric did not improve from 0.81416
#
# Epoch 00036: val_competition_metric did not improve from 0.81416
#
# Epoch 00037: val_competition_metric did not improve from 0.81416
#
# Epoch 00038: val_competition_metric did not improve from 0.81416
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00039: val_competition_metric did not improve from 0.81416
#
# Epoch 00040: val_competition_metric did not improve from 0.81416
#
# Epoch 00041: val_competition_metric did not improve from 0.81416
#
# Epoch 00042: val_competition_metric did not improve from 0.81416
#
# Epoch 00043: val_competition_metric did not improve from 0.81416
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00044: val_competition_metric did not improve from 0.81416
#
# Epoch 00045: val_competition_metric did not improve from 0.81416
#
# Epoch 00046: val_competition_metric did not improve from 0.81416
#
# Epoch 00047: val_competition_metric did not improve from 0.81416
#
# Epoch 00048: val_competition_metric did not improve from 0.81416
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00049: val_competition_metric did not improve from 0.81416
# Epoch 00049: early stopping
# Done with binary cross entropy
# Model ready for lovasz training
#
# Epoch 00001: val_metric_for_lovasz improved from -inf to 0.80330, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00002: val_metric_for_lovasz improved from 0.80330 to 0.81726, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00003: val_metric_for_lovasz did not improve from 0.81726
#
# Epoch 00004: val_metric_for_lovasz did not improve from 0.81726
#
# Epoch 00005: val_metric_for_lovasz did not improve from 0.81726
#
# Epoch 00006: val_metric_for_lovasz did not improve from 0.81726
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_metric_for_lovasz did not improve from 0.81726
#
# Epoch 00008: val_metric_for_lovasz improved from 0.81726 to 0.82828, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00009: val_metric_for_lovasz did not improve from 0.82828
#
# Epoch 00010: val_metric_for_lovasz improved from 0.82828 to 0.82957, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00011: val_metric_for_lovasz did not improve from 0.82957
#
# Epoch 00012: val_metric_for_lovasz did not improve from 0.82957
#
# Epoch 00013: val_metric_for_lovasz did not improve from 0.82957
#
# Epoch 00014: val_metric_for_lovasz did not improve from 0.82957
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00015: val_metric_for_lovasz did not improve from 0.82957
#
# Epoch 00016: val_metric_for_lovasz improved from 0.82957 to 0.83103, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00017: val_metric_for_lovasz did not improve from 0.83103
#
# Epoch 00018: val_metric_for_lovasz did not improve from 0.83103
#
# Epoch 00019: val_metric_for_lovasz did not improve from 0.83103
#
# Epoch 00020: val_metric_for_lovasz did not improve from 0.83103
# Epoch 00021: val_metric_for_lovasz improved from 0.83103 to 0.83447, saving model to models/resnet_unet_kfold_lovasz_2.h5
#
# Epoch 00022: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00023: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00024: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00025: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00027: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00028: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00029: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00030: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00031: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00032: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00033: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00034: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00035: val_metric_for_lovasz did not improve from 0.83447
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00036: val_metric_for_lovasz did not improve from 0.83447
# Epoch 00036: early stopping
# Done with training in this fold
# ['loss', 'metric_for_lovasz']
# 6206/6206 [==============================] - 98s 16ms/step
# [0.3067737335577497, 0.8344666451820821]
# 18000/18000 [==============================] - 28s 2ms/step
# 18000/18000 [==============================] - 25s 1ms/step
# ================================= FOLD 3 =============================================
# (3200, 128, 128, 1) (800, 128, 128, 1)
# Training Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Validation Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Data shape
# (13600, 128, 128, 1) (6200, 128, 128, 1)
#
# Epoch 00001: val_competition_metric improved from -inf to 0.24971, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00002: val_competition_metric improved from 0.24971 to 0.30229, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00003: val_competition_metric improved from 0.30229 to 0.37608, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00004: val_competition_metric improved from 0.37608 to 0.52900, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00005: val_competition_metric improved from 0.52900 to 0.65002, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00006: val_competition_metric improved from 0.65002 to 0.72347, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00007: val_competition_metric improved from 0.72347 to 0.73935, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00008: val_competition_metric did not improve from 0.73935
#
# Epoch 00009: val_competition_metric did not improve from 0.73935
#
# Epoch 00010: val_competition_metric improved from 0.73935 to 0.77529, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00011: val_competition_metric did not improve from 0.77529
#
# Epoch 00012: val_competition_metric improved from 0.77529 to 0.78166, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00013: val_competition_metric did not improve from 0.78166
#
# Epoch 00014: val_competition_metric did not improve from 0.78166
#
# Epoch 00015: val_competition_metric did not improve from 0.78166
#
# Epoch 00016: val_competition_metric improved from 0.78166 to 0.78660, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00017: val_competition_metric did not improve from 0.78660
#
# Epoch 00018: val_competition_metric did not improve from 0.78660
#
# Epoch 00019: val_competition_metric improved from 0.78660 to 0.79660, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00020: val_competition_metric did not improve from 0.79660
#
# Epoch 00021: val_competition_metric improved from 0.79660 to 0.79939, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00022: val_competition_metric did not improve from 0.79939
#
# Epoch 00023: val_competition_metric did not improve from 0.79939
#
# Epoch 00024: val_competition_metric did not improve from 0.79939
#
# Epoch 00025: val_competition_metric did not improve from 0.79939
#
# Epoch 00026: val_competition_metric improved from 0.79939 to 0.80897, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00027: val_competition_metric did not improve from 0.80897
#
# Epoch 00028: val_competition_metric did not improve from 0.80897
#
# Epoch 00029: val_competition_metric did not improve from 0.80897
#
# Epoch 00030: val_competition_metric did not improve from 0.80897
#
# Epoch 00031: val_competition_metric improved from 0.80897 to 0.81094, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00032: val_competition_metric did not improve from 0.81094
#
# Epoch 00033: val_competition_metric improved from 0.81094 to 0.81132, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00034: val_competition_metric improved from 0.81132 to 0.81334, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00035: val_competition_metric did not improve from 0.81334
#
# Epoch 00036: val_competition_metric did not improve from 0.81334
#
# Epoch 00037: val_competition_metric did not improve from 0.81334
#
# Epoch 00038: val_competition_metric improved from 0.81334 to 0.81500, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00039: val_competition_metric did not improve from 0.81500
#
# Epoch 00040: val_competition_metric did not improve from 0.81500
#
# Epoch 00041: val_competition_metric did not improve from 0.81500
#
# Epoch 00042: val_competition_metric improved from 0.81500 to 0.82545, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00043: val_competition_metric did not improve from 0.82545
#
# Epoch 00044: val_competition_metric did not improve from 0.82545
#
# Epoch 00045: val_competition_metric did not improve from 0.82545
#
# Epoch 00046: val_competition_metric did not improve from 0.82545
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00047: val_competition_metric did not improve from 0.82545
#
# Epoch 00048: val_competition_metric did not improve from 0.82545
#
# Epoch 00049: val_competition_metric did not improve from 0.82545
#
# Epoch 00050: val_competition_metric did not improve from 0.82545
#
# Epoch 00051: val_competition_metric did not improve from 0.82545
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00052: val_competition_metric did not improve from 0.82545
#
# Epoch 00053: val_competition_metric did not improve from 0.82545
#
# Epoch 00054: val_competition_metric did not improve from 0.82545
#
# Epoch 00055: val_competition_metric did not improve from 0.82545
#
# Epoch 00056: val_competition_metric did not improve from 0.82545
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00057: val_competition_metric did not improve from 0.82545
# Epoch 00057: early stopping
# Done with binary cross entropy
# Model ready for lovasz training
#
# Epoch 00001: val_metric_for_lovasz improved from -inf to 0.82552, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00002: val_metric_for_lovasz did not improve from 0.82552
#
# Epoch 00003: val_metric_for_lovasz did not improve from 0.82552
#
# Epoch 00004: val_metric_for_lovasz did not improve from 0.82552
#
# Epoch 00005: val_metric_for_lovasz did not improve from 0.82552
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_metric_for_lovasz did not improve from 0.82552
#
# Epoch 00007: val_metric_for_lovasz improved from 0.82552 to 0.83713, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00008: val_metric_for_lovasz improved from 0.83713 to 0.83731, saving model to models/resnet_unet_kfold_lovasz_3.h5
#
# Epoch 00009: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00010: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00011: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00012: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00013: val_metric_for_lovasz did not improve from 0.83731
# Epoch 00014: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00015: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00016: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00017: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00018: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00019: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00020: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00021: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00022: val_metric_for_lovasz did not improve from 0.83731
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00023: val_metric_for_lovasz did not improve from 0.83731
# Epoch 00023: early stopping
# Done with training in this fold
# ['loss', 'metric_for_lovasz']
# 6200/6200 [==============================] - 102s 16ms/step
# [0.32901643171523426, 0.8373064516129024]
# 18000/18000 [==============================] - 34s 2ms/step
# 18000/18000 [==============================] - 25s 1ms/step
# ================================= FOLD 4 =============================================
# (3203, 128, 128, 1) (797, 128, 128, 1)
# Training Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Validation Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Data shape
# (13606, 128, 128, 1) (6188, 128, 128, 1)
#
# Epoch 00001: val_competition_metric improved from -inf to 0.13266, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00002: val_competition_metric improved from 0.13266 to 0.25137, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00003: val_competition_metric improved from 0.25137 to 0.39627, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00004: val_competition_metric improved from 0.39627 to 0.53825, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00005: val_competition_metric improved from 0.53825 to 0.65612, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00006: val_competition_metric improved from 0.65612 to 0.65810, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00007: val_competition_metric improved from 0.65810 to 0.68473, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00008: val_competition_metric improved from 0.68473 to 0.74315, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00009: val_competition_metric improved from 0.74315 to 0.74682, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00010: val_competition_metric did not improve from 0.74682
#
# Epoch 00011: val_competition_metric did not improve from 0.74682
#
# Epoch 00012: val_competition_metric improved from 0.74682 to 0.76383, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00013: val_competition_metric did not improve from 0.76383
#
# Epoch 00014: val_competition_metric did not improve from 0.76383
#
# Epoch 00015: val_competition_metric did not improve from 0.76383
#
# Epoch 00016: val_competition_metric did not improve from 0.76383
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_competition_metric did not improve from 0.76383
#
# Epoch 00018: val_competition_metric improved from 0.76383 to 0.80050, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00019: val_competition_metric did not improve from 0.80050
#
# Epoch 00020: val_competition_metric did not improve from 0.80050
#
# Epoch 00021: val_competition_metric did not improve from 0.80050
#
# Epoch 00022: val_competition_metric did not improve from 0.80050
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_competition_metric did not improve from 0.80050
#
# Epoch 00024: val_competition_metric did not improve from 0.80050
#
# Epoch 00025: val_competition_metric improved from 0.80050 to 0.80588, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00026: val_competition_metric did not improve from 0.80588
#
# Epoch 00027: val_competition_metric did not improve from 0.80588
#
# Epoch 00028: val_competition_metric did not improve from 0.80588
#
# Epoch 00029: val_competition_metric improved from 0.80588 to 0.80787, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00030: val_competition_metric did not improve from 0.80787
#
# Epoch 00031: val_competition_metric did not improve from 0.80787
#
# Epoch 00032: val_competition_metric did not improve from 0.80787
#
# Epoch 00033: val_competition_metric did not improve from 0.80787
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00034: val_competition_metric did not improve from 0.80787
#
# Epoch 00035: val_competition_metric did not improve from 0.80787
#
# Epoch 00036: val_competition_metric did not improve from 0.80787
#
# Epoch 00037: val_competition_metric did not improve from 0.80787
#
# Epoch 00038: val_competition_metric did not improve from 0.80787
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00039: val_competition_metric did not improve from 0.80787
#
# Epoch 00040: val_competition_metric did not improve from 0.80787
#
# Epoch 00041: val_competition_metric did not improve from 0.80787
#
# Epoch 00042: val_competition_metric did not improve from 0.80787
#
# Epoch 00043: val_competition_metric did not improve from 0.80787
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00044: val_competition_metric did not improve from 0.80787
# Epoch 00044: early stopping
# Done with binary cross entropy
# Model ready for lovasz training
#
# Epoch 00001: val_metric_for_lovasz improved from -inf to 0.79428, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00002: val_metric_for_lovasz improved from 0.79428 to 0.80533, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00003: val_metric_for_lovasz improved from 0.80533 to 0.81938, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00004: val_metric_for_lovasz did not improve from 0.81938
#
# Epoch 00005: val_metric_for_lovasz did not improve from 0.81938
#
# Epoch 00006: val_metric_for_lovasz did not improve from 0.81938
#
# Epoch 00007: val_metric_for_lovasz did not improve from 0.81938
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_metric_for_lovasz did not improve from 0.81938
#
# Epoch 00009: val_metric_for_lovasz improved from 0.81938 to 0.82668, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00010: val_metric_for_lovasz did not improve from 0.82668
#
# Epoch 00011: val_metric_for_lovasz did not improve from 0.82668
#
# Epoch 00012: val_metric_for_lovasz did not improve from 0.82668
#
# Epoch 00013: val_metric_for_lovasz did not improve from 0.82668
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00014: val_metric_for_lovasz did not improve from 0.82668
#
# Epoch 00015: val_metric_for_lovasz improved from 0.82668 to 0.83439, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00016: val_metric_for_lovasz did not improve from 0.83439
#
# Epoch 00017: val_metric_for_lovasz did not improve from 0.83439
#
# Epoch 00018: val_metric_for_lovasz did not improve from 0.83439
#
# Epoch 00019: val_metric_for_lovasz did not improve from 0.83439
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00020: val_metric_for_lovasz did not improve from 0.83439
#
# Epoch 00021: val_metric_for_lovasz improved from 0.83439 to 0.83578, saving model to models/resnet_unet_kfold_lovasz_4.h5
#
# Epoch 00022: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00023: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00024: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00025: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00026: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00027: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00028: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00029: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00030: val_metric_for_lovasz did not improve from 0.83578
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00031: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00032: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00033: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00034: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00035: val_metric_for_lovasz did not improve from 0.83578
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00036: val_metric_for_lovasz did not improve from 0.83578
# Epoch 00036: early stopping
# Done with training in this fold
# ['loss', 'metric_for_lovasz']
# 6188/6188 [==============================] - 106s 17ms/step
# [0.3003780350184493, 0.8357789269553975]
# 18000/18000 [==============================] - 43s 2ms/step
# 18000/18000 [==============================] - 27s 1ms/step
# ================================= FOLD 5 =============================================
# (3204, 128, 128, 1) (796, 128, 128, 1)
# Training Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Validation Augmentation
# Flipping
# Random crop and resize
# Rotations
# Rolling
# Data shape
# (13608, 128, 128, 1) (6184, 128, 128, 1)
#
# Epoch 00001: val_competition_metric improved from -inf to 0.11884, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00002: val_competition_metric improved from 0.11884 to 0.24743, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00003: val_competition_metric improved from 0.24743 to 0.37867, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00004: val_competition_metric improved from 0.37867 to 0.56463, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00005: val_competition_metric improved from 0.56463 to 0.68013, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00006: val_competition_metric improved from 0.68013 to 0.68376, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00007: val_competition_metric improved from 0.68376 to 0.70500, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00008: val_competition_metric improved from 0.70500 to 0.75530, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00009: val_competition_metric improved from 0.75530 to 0.76514, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00010: val_competition_metric did not improve from 0.76514
#
# Epoch 00011: val_competition_metric did not improve from 0.76514
#
# Epoch 00012: val_competition_metric did not improve from 0.76514
#
# Epoch 00013: val_competition_metric did not improve from 0.76514
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_competition_metric did not improve from 0.76514
#
# Epoch 00015: val_competition_metric improved from 0.76514 to 0.79018, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00016: val_competition_metric improved from 0.79018 to 0.80222, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00017: val_competition_metric improved from 0.80222 to 0.80307, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00018: val_competition_metric did not improve from 0.80307
#
# Epoch 00019: val_competition_metric did not improve from 0.80307
#
# Epoch 00020: val_competition_metric did not improve from 0.80307
#
# Epoch 00021: val_competition_metric did not improve from 0.80307
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_competition_metric did not improve from 0.80307
#
# Epoch 00023: val_competition_metric improved from 0.80307 to 0.81072, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00024: val_competition_metric did not improve from 0.81072
#
# Epoch 00025: val_competition_metric improved from 0.81072 to 0.81303, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00026: val_competition_metric did not improve from 0.81303
#
# Epoch 00027: val_competition_metric improved from 0.81303 to 0.81564, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00028: val_competition_metric did not improve from 0.81564
#
# Epoch 00029: val_competition_metric did not improve from 0.81564
#
# Epoch 00030: val_competition_metric did not improve from 0.81564
#
# Epoch 00031: val_competition_metric did not improve from 0.81564
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_competition_metric did not improve from 0.81564
#
# Epoch 00033: val_competition_metric did not improve from 0.81564
#
# Epoch 00034: val_competition_metric did not improve from 0.81564
#
# Epoch 00035: val_competition_metric did not improve from 0.81564
#
# Epoch 00036: val_competition_metric did not improve from 0.81564
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00037: val_competition_metric did not improve from 0.81564
#
# Epoch 00038: val_competition_metric did not improve from 0.81564
#
# Epoch 00039: val_competition_metric did not improve from 0.81564
#
# Epoch 00040: val_competition_metric did not improve from 0.81564
#
# Epoch 00041: val_competition_metric did not improve from 0.81564
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00042: val_competition_metric did not improve from 0.81564
# Epoch 00042: early stopping
# Done with binary cross entropy
# Model ready for lovasz training
#
# Epoch 00001: val_metric_for_lovasz improved from -inf to 0.81818, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00002: val_metric_for_lovasz did not improve from 0.81818
#
# Epoch 00003: val_metric_for_lovasz did not improve from 0.81818
#
# Epoch 00004: val_metric_for_lovasz did not improve from 0.81818
#
# Epoch 00005: val_metric_for_lovasz did not improve from 0.81818
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_metric_for_lovasz did not improve from 0.81818
#
# Epoch 00007: val_metric_for_lovasz improved from 0.81818 to 0.83270, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00008: val_metric_for_lovasz did not improve from 0.83270
#
# Epoch 00009: val_metric_for_lovasz did not improve from 0.83270
#
# Epoch 00010: val_metric_for_lovasz did not improve from 0.83270
#
# Epoch 00011: val_metric_for_lovasz improved from 0.83270 to 0.83313, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00012: val_metric_for_lovasz did not improve from 0.83313
#
# Epoch 00013: val_metric_for_lovasz did not improve from 0.83313
#
# Epoch 00014: val_metric_for_lovasz did not improve from 0.83313
#
# Epoch 00015: val_metric_for_lovasz did not improve from 0.83313
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_metric_for_lovasz did not improve from 0.83313
#
# Epoch 00017: val_metric_for_lovasz improved from 0.83313 to 0.83821, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00018: val_metric_for_lovasz did not improve from 0.83821
#
# Epoch 00019: val_metric_for_lovasz did not improve from 0.83821
#
# Epoch 00020: val_metric_for_lovasz did not improve from 0.83821
#
# Epoch 00021: val_metric_for_lovasz did not improve from 0.83821
#
# Epoch 00022: val_metric_for_lovasz improved from 0.83821 to 0.83845, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00023: val_metric_for_lovasz did not improve from 0.83845
#
# Epoch 00024: val_metric_for_lovasz did not improve from 0.83845
#
# Epoch 00025: val_metric_for_lovasz did not improve from 0.83845
#
# Epoch 00026: val_metric_for_lovasz did not improve from 0.83845
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_metric_for_lovasz did not improve from 0.83845
#
# Epoch 00028: val_metric_for_lovasz improved from 0.83845 to 0.83857, saving model to models/resnet_unet_kfold_lovasz_5.h5
#
# Epoch 00029: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00030: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00031: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00032: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00033: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00034: val_metric_for_lovasz did not improve from 0.83857
# Epoch 00035: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00036: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00037: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00038: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00039: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00040: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00041: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00042: val_metric_for_lovasz did not improve from 0.83857
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00043: val_metric_for_lovasz did not improve from 0.83857
# Epoch 00043: early stopping
# Done with training in this fold
# ['loss', 'metric_for_lovasz']
# 6184/6184 [==============================] - 112s 18ms/step
# [0.2959372318578091, 0.8385672703751617]
# 18000/18000 [==============================] - 47s 3ms/step
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-7f936f306f58> in <module>()
#      77
#      78     # making test predictions
# ---> 79     preds_test=preds_test+(model.predict(X_test,verbose=1))/n_folds
#      80
#      81     # tta
#
# MemoryError:

# %% [markdown]
# ## Test Data
# First we'll get the test data. This takes a while, it's 18000 samples.

# %%
# %%time

preds_name="resnet_5_fold_64_batch_loavsz"
# saving the test predictions
name="test_predicitons/"+preds_name
np.save(name,preds_test)

# saving the flip predictions
name="test_predicitons/"+preds_name+"tta"
np.save(name,preds_test_flip)

# %% [markdown]
# ## Prepare Submission
# We need to prepare the submission.

# %%
def downsample(img):# not used
    if img.shape[0]==101:
        return img
    return resize(img, (101,101), mode='constant', 
                  preserve_range=True,clip=True,anti_aliasing=False)


def rle_encode(im):
    '''
    im: numpy array, 1-mask, 0-background
    Returns run length as string
    '''
    pixels = im.flatten(order='F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
threshold=0.0
sub=sample.copy()

for index,name in tqdm.tqdm_notebook(enumerate(sub['id'].values),total=sub['id'].shape[0]):
    downsampled_img=downsample(preds_test[index].reshape(128,128))
    downsampled_img=downsampled_img>threshold
    sub.loc[index,'rle_mask']=rle_encode(downsampled_img)

print("Number of empty predictions are",sub.loc[sub['rle_mask']==""].shape[0])
sub.head()

# %%
tta_sub=sample.copy()

preds_test_final=(preds_test+preds_test_flip)/2

for index,name in tqdm.tqdm_notebook(enumerate(tta_sub['id'].values),total=tta_sub['id'].shape[0]):
    downsampled_img=downsample(preds_test_final[index].reshape(128,128))
    downsampled_img=downsampled_img>threshold
    tta_sub.loc[index,'rle_mask']=rle_encode(downsampled_img)

print("Number of empty predictions are",tta_sub.loc[tta_sub['rle_mask']==""].shape[0])
tta_sub.head()

# %%
corrected_sub=sub.copy()
c=0

wrong_preds_ids=[]
for i in indextest:
    if sub.loc[i,'rle_mask']!="":
        wrong_preds_ids.append(sub['id'][i])
        
        # correcting the predictions
        corrected_sub.loc[i,'rle_mask']=""
        
        c=c+1

print(c,"predicitions are wrong")
print("After correction")
print("Number of final empty predictions are",corrected_sub.loc[corrected_sub['rle_mask']==""].shape[0])

# %% [markdown]
# ## SAVING THE FILE

# %%
save_filename="resnet_2_blocks_unet_64_batch_5_folds_inc_rolling_lovasz.csv"

sub.to_csv(save_filename,index=False)

tta_sub.to_csv("tta_"+save_filename,index=False)

print("Done")

# %% [markdown]
# ## THRESHOLD CHANGE

# %%
threshold=0.05
tta_sub=sample.copy()

preds_test_final=(preds_test+preds_test_flip)/2

for index,name in tqdm.tqdm_notebook(enumerate(tta_sub['id'].values),total=tta_sub['id'].shape[0]):
    downsampled_img=downsample(preds_test_final[index].reshape(128,128))
    downsampled_img=downsampled_img>threshold
    tta_sub.loc[index,'rle_mask']=rle_encode(downsampled_img)

print("Number of empty predictions are",tta_sub.loc[tta_sub['rle_mask']==""].shape[0])
tta_sub.head()

# %%
tta_sub.to_csv("tta_0.47_threshold_"+save_filename,index=False)
